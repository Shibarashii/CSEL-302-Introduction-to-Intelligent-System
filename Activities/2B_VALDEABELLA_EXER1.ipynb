# %%
import pandas as pd
import matplotlib.pyplot as plt

email = pd.read_csv('Email_Exchanges.csv', encoding = 'latin-1')
inventory = pd.read_csv('Inventory_Records.csv', encoding = 'latin-1')
security = pd.read_csv('Security_Camera_Logs.csv', encoding = 'latin-1')
visitor = pd.read_csv('Visitor_Logs.csv', encoding = 'latin-1')

# %%
eStat = email.describe()
iStat = inventory.describe()
sStat = security.describe()
vStat = visitor.describe()

vStat.head()
# Out:
#               Date Entry Time Exit Time Visitor ID        Exhibit Visited
# count            9          9         9          9                      9
# unique           5          9         7          9                      3
# top     2024-05-10   10:00 AM  03:00 PM      V1234  Ancient World Exhibit
# freq             2          1         2          1                      6

# %%
eStat.head()
# Out:
#               Date                        From                           To  \
# count            5                           5                            5
# unique           5                           5                            4
# top     2024-05-08  curator@newfieldmuseum.org  security@newfieldmuseum.org
# freq             1                           1                            2
#
#                   Subject                                               Body
# count                   5                                                  5
# unique                  5                                                  5
# top     Security Concerns  I've noticed an increase in visitors lingering...
# freq                    1                                                  1

# %%
iStat.head()
# Out:
#        Item ID       Description    Last Known Location Movement Date  \
# count        5                 5                      5             5
# unique       5                 5                      5             5
# top      SP001  Sapphire Phoenix  Ancient World Exhibit    2024-05-09
# freq         1                 1                      1             1
#
#        Authorized Personnel
# count                     5
# unique                    5
# top                John Doe
# freq                      1

# %%
sStat.head()
# Out:
#        Camera ID   Location            Timestamp Detected Movement  \
# count          9          9                    9                 9
# unique         9          4                    9                 2
# top         C101  Main Hall  2024-05-10 11:00 PM               Yes
# freq           1          3                    1                 7
#
#        Notable Observations
# count                     9
# unique                    8
# top                       -
# freq                      2

# %% [markdown]
# **John Doe** - He was last seen at Ancient World Exhibit and his description is the missing item. Other Authorized Personnel seems like they have no connection because of their last known location and description. John Doe stands out
#
# **3 ANCIENT EXHIBIT VISITORS (c102 is dismissed)**
#
#
#
# **V1239** - *2024- 10:30AM - 1:30PM* at AWE, Security Camera Logs say that an Unattended bag was spotted at 10:45AM, he would fit the timestamp
#
#
# **V1242** - 2024-05-14 at 3:00PM to 5:30PM AWE, Security Camera logs say that he was avoiding camera at 3:30PM, he would fit the timestamp
